# %% [markdown]
# <a href="https://colab.research.google.com/github/TamurOne10/Campus_Placement_Analysis-and-ML-model-/blob/main/IBM1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Final Project Notebook

# %% [markdown]
# ## Introduction
# This notebook covers key elements of data science including languages, libraries, tools, and some simple arithmetic operations. It is structured for final project evaluation.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Java
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras
# - Seaborn

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Category        | Description                    |
# |----------------|----------------|--------------------------------|
# | Jupyter        | Notebook        | Interactive coding environment |
# | RStudio        | IDE             | IDE for R programming          |
# | TensorFlow     | Library         | Deep learning framework        |
# | Power BI       | Visualization   | Business analytics tool        |
# | Apache Spark   | Big Data        | Distributed data processing    |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# The following code cells will demonstrate simple arithmetic operations such as addition and multiplication.

# %% [markdown]
# # Multiply and add numbers
# a = 5
# b = 10
# result = (a * b) + 20
# print("Result:", result)

# %% [markdown]
# # Convert minutes to hours
# minutes = 200
# hours = minutes / 60
# print("Hours:", hours)

# %% [markdown]
# ## Objectives
# - Understand key data science concepts
# - List programming languages and libraries used in data science
# - Use markdown and code cells effectively
# - Demonstrate arithmetic operations in code
# - Practice sharing notebooks through GitHub

# %% [markdown]
# ## Author
# Tamoor Abbas
